# %%
# %config Completer.use_jedi = False

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('train.csv')
df.tail()
# Out:
#             id  d_l_match_yn  d_m_match_yn  d_s_match_yn  h_l_match_yn  \
# 501946  501946         False         False         False          True
# 501947  501947          True          True         False          True
# 501948  501948          True          True          True          True
# 501949  501949          True         False         False          True
# 501950  501950          True          True          True          True
#
#         h_m_match_yn  h_s_match_yn  person_attribute_a  person_attribute_a_1  \
# 501946         False         False                   1                     1
# 501947         False         False                   1                     6
# 501948         False         False                   1                     7
# 501949         False         False                   1                     1
# 501950         False         False                   1                     6
#
#         person_attribute_b  person_prefer_c  person_prefer_d_1  \
# ...

# %%
df['d_l_match_yn'].value_counts()
# Out:
# True     315268
# False    186683
# Name: d_l_match_yn, dtype: int64

# %%
df['d_m_match_yn'].value_counts()
# Out:
# False    368324
# True     133627
# Name: d_m_match_yn, dtype: int64

# %%
df['d_s_match_yn'].value_counts()
# Out:
# False    426694
# True      75257
# Name: d_s_match_yn, dtype: int64

# %%
df[(df['d_l_match_yn'] == True) & (df['d_m_match_yn'] == True) & (df['d_s_match_yn'] == True)].target.value_counts()
# Out:
# 1    45457
# 0    29800
# Name: target, dtype: int64

# %%
df['person_rn'].value_counts()
# Out:
# 627445     20
# 1047079    19
# 241140     19
# 827703     19
# 1016996    18
#            ..
# 798856      1
# 54141       1
# 467843      1
# 988037      1
# 907205      1
# Name: person_rn, Length: 300177, dtype: int64

# %%
df[df['person_rn']==627445].target.value_counts()
# Out:
# 1    12
# 0     8
# Name: target, dtype: int64

# %%
df['contents_attribute_l'].value_counts()
# Out:
# 759     15373
# 1648    11984
# 1835    10967
# 861      9899
# 572      9604
#         ...
# 9           1
# 751         1
# 1787        1
# 170         1
# 1365        1
# Name: contents_attribute_l, Length: 1752, dtype: int64

# %%
df['contents_attribute_j_1'].value_counts()
# Out:
# 5     330790
# 10     89307
# 3      30664
# 4      19649
# 9      19115
# 6      10808
# 2       1416
# 8        137
# 1         65
# Name: contents_attribute_j_1, dtype: int64

# %%
df['person_rn'].nunique()
# Out:
# 300177

# %%
df['contents_rn'].nunique()
# Out:
# 283359

# %%
df[(df['target'] == 1)].contents_rn.value_counts()
# Out:
# 22078     34
# 138209    28
# 76824     26
# 402922    23
# 668672    21
#           ..
# 345720     1
# 412538     1
# 152441     1
# 20389      1
# 149367     1
# Name: contents_rn, Length: 155277, dtype: int64

# %%
df[df['contents_rn'] == 22078].describe()
# Out:
#                   id  person_attribute_a  person_attribute_a_1  \
# count      39.000000           39.000000             39.000000
# mean   317664.641026            1.256410              2.692308
# std     87299.256766            0.442359              2.363693
# min    120004.000000            1.000000              0.000000
# 25%    258231.500000            1.000000              1.000000
# 50%    365121.000000            1.000000              2.000000
# 75%    403809.500000            1.500000              4.500000
# max    428591.000000            2.000000              7.000000
#
#        person_attribute_b  person_prefer_c  person_prefer_d_1  \
# count            39.00000        39.000000          39.000000
# mean              2.74359         3.589744         622.205128
# std               0.99255         1.802308         259.982204
# min               1.00000         1.000000          27.000000
# 25%               2.00000         1.000000         697.000000
# ...
