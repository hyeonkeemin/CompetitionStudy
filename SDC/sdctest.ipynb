# %%
import pandas as pd

# %%
df1 = pd.read_csv('submission.csv')
df2 = pd.read_csv('submission_1.csv')

# %%
result = [i+1 for i, value in enumerate(zip(df1['digit_3'], df2['digit_3'])) if value[0] != value[1]]

# %%
len(result)
# Out:
# 8300

# %%
result
# Out:
# [13,
#  22,
#  38,
#  54,
#  58,
#  62,
#  64,
#  65,
#  83,
#  86,
#  92,
#  95,
#  107,
#  122,
#  123,
#  129,
#  145,
#  146,
#  156,
#  171,
#  176,
#  183,
#  195,
#  207,
#  218,
#  225,
#  226,
#  227,
#  231,
#  232,
#  237,
#  238,
#  240,
#  241,
#  260,
#  261,
#  263,
#  288,
#  310,
#  315,
#  316,
#  325,
#  360,
#  365,
#  368,
#  375,
#  377,
#  432,
#  445,
#  449,
#  458,
#  480,
#  486,
#  500,
#  504,
#  514,
#  522,
#  526,
#  551,
#  571,
#  572,
#  575,
#  588,
#  641,
#  648,
#  656,
#  659,
#  664,
#  665,
#  672,
#  677,
#  706,
#  707,
#  715,
#  721,
#  732,
#  742,
#  748,
#  764,
#  816,
#  825,
#  841,
#  869,
#  886,
#  893,
#  899,
#  901,
#  917,
#  932,
#  938,
#  942,
#  976,
#  985,
#  995,
#  1002,
#  1003,
#  1009,
#  1012,
#  1026,
#  1036,
#  1065,
#  1077,
#  1078,
#  1079,
#  1089,
#  1090,
#  1103,
#  1105,
#  1111,
#  1117,
#  1119,
#  1136,
#  1155,
#  1156,
#  1157,
#  1163,
#  1169,
#  1190,
#  1200,
#  1216,
#  1249,
#  1265,
# ...
